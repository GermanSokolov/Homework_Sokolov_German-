# %%
import re

# %%
saved={}
fial_result=None
while True:
    expression = input('Введите выражение: ')
    if expression == 'exit':
        print('Завершение работы')
        break
    if expression == 'to double':
        if final_result == None:
            print('Ещё ничего нет')
            continue
        else:
            print(((final_result['whole']*final_result['denominator'])+final_result['numerator'])/final_result['denominator'])
            continue
    exp_list=re.split(' ', expression)
    exp_list2=re.split(' ', expression)
    if ('save' in exp_list):
        if len(saved)>9:
            print('нельзя сохранить')
            continue
        else:
            saved[exp_list[1]]=under_fin
            print('соханение успешно')
            continue
    if ('delete' in exp_list):
            del saved[exp_list[1]]
            print('удаление успешно')
            continue
    
    for i in range(0, len(exp_list)):
        if (re.search(r'([0-9]+)', exp_list[i])) and not(re.search(r'([0-9]*)\([0-9]+/[0-9]+\)', exp_list[i])):
            exp_list[i]=int(exp_list[i])
    for i in range(0, len(exp_list2)):
        if (re.search(r'([0-9]+)', exp_list2[i])) and not(re.search(r'([0-9]*)\([0-9]+/[0-9]+\)', exp_list2[i])):
            exp_list2[i]=int(exp_list2[i])
    
    p = re.compile(r'[0-9]*\([0-9]+/[0-9]+\)')
    o = -1
    for i in exp_list:
        o+=1
        m = re.compile(r'([0-9]*)\([0-9]+/[0-9]+\)')
        s = re.compile(r'[0-9]*\(([0-9]+)/[0-9]+\)')
        r = re.compile(r'[0-9]*\([0-9]+/([0-9]+)\)')
        if type(i)==str:
            if p.match(i):
                u={}
                u['whole'] = m.findall(i)[0]
                u['numerator'] = s.findall(i)[0]
                u['denominator'] = r.findall(i)[0]
                exp_list[o]=u
                exp_list2[o]=u
                
    while len(exp_list2)>1:
        ind=-1
        for i in exp_list:
            ind+=1
            if type(i)==str:
                if (re.search(r'\*', i)):
                    if type(exp_list2[ind-1])==int and type(exp_list2[ind+1])==int:
                        result=exp_list2[ind-1]*exp_list2[ind+1]
                        exp_list2.pop(ind+1)
                        exp_list2.pop(ind)
                        exp_list2.pop(ind-1)
                        exp_list2.insert(ind-1, result)
                    elif type(exp_list[ind-1])==dict and type(exp_list[ind+1])==dict:
                        result={}
                        result['whole'] = 0
                        result['numerator'] = (int(exp_list[ind-1]['whole']) * int(exp_list[ind-1]['denominator']) + int(exp_list[ind-1]['numerator']))*((int(exp_list[ind+1]['whole']) * int(exp_list[ind+1]['denominator']))+int(exp_list[ind+1]['numerator']))
                        result['denominator'] = int(exp_list[ind-1]['denominator'])*int(exp_list[ind+1]['denominator'])
                        exp_list2.pop(ind+1)
                        exp_list2.pop(ind)
                        exp_list2.pop(ind-1)
                        exp_list2.insert(ind-1, result)
                    elif type(exp_list[ind-1])==int and type(exp_list[ind+1])==dict:
                        result={}
                        result['whole'] = 0
                        result['numerator'] = exp_list[ind-1]*((int(exp_list[ind+1]['whole']) * int(exp_list[ind+1]['denominator']))+int(exp_list[ind+1]['numerator']))
                        result['denominator'] = int(exp_list[ind+1]['denominator'])
                        exp_list2.pop(ind+1)
                        exp_list2.pop(ind)
                        exp_list2.pop(ind-1)
                        exp_list2.insert(ind-1, result)
                    elif type(exp_list[ind-1])==dict and type(exp_list[ind+1])==int:
                        result={}
                        result['whole'] = 0
                        result['numerator'] = exp_list[ind+1]*((int(exp_list[ind-1]['whole']) * int(exp_list[ind-1]['denominator']))+int(exp_list[ind-1]['numerator']))
                        result['denominator'] = int(exp_list[ind+1]['denominator'])
                        exp_list2.pop(ind+1)
                        exp_list2.pop(ind)
                        exp_list2.pop(ind-1)
                        exp_list2.insert(ind-1, result)
                if (re.search(r'\/', i)):
                    if type(exp_list2[ind-1])==int and type(exp_list2[ind+1])==int:
                        result=exp_list2[ind-1]/exp_list2[ind+1]
                        exp_list2.pop(ind+1)
                        exp_list2.pop(ind)
                        exp_list2.pop(ind-1)
                        exp_list2.insert(ind-1, result)
                    elif type(exp_list[ind-1])==dict and type(exp_list[ind+1])==dict:
                        result={}
                        result['whole'] = 0
                        result['numerator'] = (int(exp_list[ind-1]['whole']) * int(exp_list[ind-1]['denominator']) + int(exp_list[ind-1]['numerator']))*int(exp_list[ind+1]['denominator'])
                        result['denominator'] = int(exp_list[ind-1]['denominator'])*((int(exp_list[ind+1]['whole']) * int(exp_list[ind+1]['denominator']))+int(exp_list[ind+1]['numerator']))
                        exp_list2.pop(ind+1)
                        exp_list2.pop(ind)
                        exp_list2.pop(ind-1)
                        exp_list2.insert(ind-1, result)
                    elif type(exp_list[ind-1])==int and type(exp_list[ind+1])==dict:
                        result={}
                        result['whole'] = 0
                        result['numerator'] = exp_list[ind-1]*int(exp_list[ind+1]['denominator'])
                        result['denominator'] = ((int(exp_list[ind+1]['whole']) * int(exp_list[ind+1]['denominator']))+int(exp_list[ind+1]['numerator']))
                        exp_list2.pop(ind+1)
                        exp_list2.pop(ind)
                        exp_list2.pop(ind-1)
                        exp_list2.insert(ind-1, result)
                    elif type(exp_list[ind-1])==dict and type(exp_list[ind+1])==int:
                        result={}
                        result['whole'] = 0
                        result['numerator'] = exp_list[ind+1]*int(exp_list[ind-1]['denominator'])
                        result['denominator'] = ((int(exp_list[ind-1]['whole']) * int(exp_list[ind-1]['denominator']))+int(exp_list[ind-1]['numerator']))
                        exp_list2.pop(ind+1)
                        exp_list2.pop(ind)
                        exp_list2.pop(ind-1)
                        exp_list2.insert(ind-1, result)
                if (re.search(r'\+', i)):
                    if type(exp_list2[ind-1])==int and type(exp_list2[ind+1])==int:
                        result=exp_list2[ind-1]+exp_list2[ind+1]
                        exp_list2.pop(ind+1)
                        exp_list2.pop(ind)
                        exp_list2.pop(ind-1)
                        exp_list2.insert(ind-1, result)
                    elif type(exp_list[ind-1])==dict and type(exp_list[ind+1])==dict:
                        result={}
                        result['whole'] = 0
                        result['numerator'] = ((int(exp_list[ind-1]['whole']) * int(exp_list[ind-1]['denominator']) + int(exp_list[ind-1]['numerator']))*int(exp_list[ind+1]['denominator']))+((int(exp_list[ind+1]['whole']) * int(exp_list[ind+1]['denominator']) + int(exp_list[ind+1]['numerator']))*int(exp_list[ind-1]['denominator']))
                        result['denominator'] = int(exp_list[ind-1]['denominator'])*int(exp_list[ind+1]['denominator'])
                        exp_list2.pop(ind+1)
                        exp_list2.pop(ind)
                        exp_list2.pop(ind-1)
                        exp_list2.insert(ind-1, result)
                    elif type(exp_list[ind-1])==int and type(exp_list[ind+1])==dict:
                        result={}
                        result['whole'] = 0
                        result['numerator'] = (exp_list[ind-1]*int(exp_list[ind+1]['denominator'])) + ((int(exp_list[ind+1]['whole']) * int(exp_list[ind+1]['denominator']))+int(exp_list[ind+1]['numerator']))
                        result['denominator'] = int(exp_list[ind+1]['denominator'])
                        exp_list2.pop(ind+1)
                        exp_list2.pop(ind)
                        exp_list2.pop(ind-1)
                        exp_list2.insert(ind-1, result)
                    elif type(exp_list[ind-1])==dict and type(exp_list[ind+1])==int:
                        result={}
                        result['whole'] = 0
                        result['numerator'] = ((int(exp_list[ind-1]['whole']) * int(exp_list[ind-1]['denominator']))+int(exp_list[ind-1]['numerator'])) + (exp_list[ind+1]*int(exp_list[ind-1]['denominator']))
                        result['denominator'] = int(exp_list[ind-1]['denominator'])
                        exp_list2.pop(ind+1)
                        exp_list2.pop(ind)
                        exp_list2.pop(ind-1)
                        exp_list2.insert(ind-1, result)
                if (re.search(r'\-', i)):
                    if type(exp_list2[ind-1])==int and type(exp_list2[ind+1])==int:
                        result=exp_list2[ind-1]-exp_list2[ind+1]
                        exp_list2.pop(ind+1)
                        exp_list2.pop(ind)
                        exp_list2.pop(ind-1)
                        exp_list2.insert(ind-1, result)
                    elif type(exp_list[ind-1])==dict and type(exp_list[ind+1])==dict:
                        result={}
                        result['whole'] = 0
                        result['numerator'] = ((int(exp_list[ind-1]['whole']) * int(exp_list[ind-1]['denominator']) + int(exp_list[ind-1]['numerator']))*int(exp_list[ind+1]['denominator']))-((int(exp_list[ind+1]['whole']) * int(exp_list[ind+1]['denominator']) + int(exp_list[ind+1]['numerator']))*int(exp_list[ind-1]['denominator']))
                        result['denominator'] = int(exp_list[ind-1]['denominator'])*int(exp_list[ind+1]['denominator'])
                        exp_list2.pop(ind+1)
                        exp_list2.pop(ind)
                        exp_list2.pop(ind-1)
                        exp_list2.insert(ind-1, result)
                    elif type(exp_list[ind-1])==int and type(exp_list[ind+1])==dict:
                        result={}
                        result['whole'] = 0
                        result['numerator'] = (exp_list[ind-1]*int(exp_list[ind+1]['denominator'])) - ((int(exp_list[ind+1]['whole']) * int(exp_list[ind+1]['denominator']))+int(exp_list[ind+1]['numerator']))
                        result['denominator'] = int(exp_list[ind+1]['denominator'])
                        exp_list2.pop(ind+1)
                        exp_list2.pop(ind)
                        exp_list2.pop(ind-1)
                        exp_list2.insert(ind-1, result)
                    elif type(exp_list[ind-1])==dict and type(exp_list[ind+1])==int:
                        result={}
                        result['whole'] = 0
                        result['numerator'] = ((int(exp_list[ind-1]['whole']) * int(exp_list[ind-1]['denominator']))-int(exp_list[ind-1]['numerator'])) + (exp_list[ind+1]*int(exp_list[ind-1]['denominator']))
                        result['denominator'] = int(exp_list[ind-1]['denominator'])
                        exp_list2.pop(ind+1)
                        exp_list2.pop(ind)
                        exp_list2.pop(ind-1)
                        exp_list2.insert(ind-1, result)
            exp_list=exp_list2
            continue
    
    final_result=exp_list2[0]
    if type(final_result)==int or type(final_result)==float:
        under_fin=final_result
        print(under_fin)
    elif final_result['numerator']==0:
        ff_result=final_result['whole']
        under_fin=f'{ff_result}'
        print(under_fin)
    elif final_result['numerator']==final_result['denominator']:
        ff_result=final_result['whole']+1
        under_fin=f'{ff_result}'
        print(under_fin)
    elif final_result['whole']==0:
        ff1=final_result['numerator']
        ff2=final_result['denominator']
        under_fin=f'{ff1}/{ff2}'
        print(under_fin)
    else:
        ff1=final_result['whole']
        ff2=final_result['numerator']
        ff3=final_result['denominator']
        under_fin=f'{ff1}({ff2}/{ff3})'
        print(under_fin)
# Out:
# Введите выражение: 3 / 2
# 1.5
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-87-443fd4cec228> in <module>
#       2 fial_result=None
#       3 while True:
# ----> 4     expression = input('Введите выражение: ')
#       5     if expression == 'exit':
#       6         print('Завершение работы')
#
# ~\anaconda3\lib\site-packages\ipykernel\kernelbase.py in raw_input(self, prompt)
#     858                 "raw_input was called, but this frontend does not support input requests."
#     859             )
# --> 860         return self._input_request(str(prompt),
#     861             self._parent_ident,
#     862             self._parent_header,
#
# ~\anaconda3\lib\site-packages\ipykernel\kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     902             except KeyboardInterrupt:
# ...

# %%
for i in range(0, len(exp_list)):
    if (re.search(r'([0-9]+)', exp_list[i])) and not(re.search(r'([0-9]*)\([0-9]+/[0-9]+\)', exp_list[i])):
        exp_list[i]=int(exp_list[i])
print(exp_list)
for i in range(0, len(exp_list2)):
    if (re.search(r'([0-9]+)', exp_list2[i])) and not(re.search(r'([0-9]*)\([0-9]+/[0-9]+\)', exp_list2[i])):
        exp_list2[i]=int(exp_list2[i])
print(exp_list2)
# Out:
# ['2(1/2)', '-', '2(1/2)']
# ['2(1/2)', '-', '2(1/2)']

# %%
p = re.compile(r'[0-9]*\([0-9]+/[0-9]+\)')
o = -1
for i in exp_list:
    o+=1
    m = re.compile(r'([0-9]*)\([0-9]+/[0-9]+\)')
    s = re.compile(r'[0-9]*\(([0-9]+)/[0-9]+\)')
    r = re.compile(r'[0-9]*\([0-9]+/([0-9]+)\)')
    if type(i)==str:
        if p.match(i):
            u={}
            u['whole'] = m.findall(i)[0]
            u['numerator'] = s.findall(i)[0]
            u['denominator'] = r.findall(i)[0]
            exp_list[o]=u
            exp_list2[o]=u
print(exp_list)
print(exp_list2)
# Out:
# [{'whole': '2', 'numerator': '1', 'denominator': '2'}, '-', {'whole': '2', 'numerator': '1', 'denominator': '2'}]
# [{'whole': '2', 'numerator': '1', 'denominator': '2'}, '-', {'whole': '2', 'numerator': '1', 'denominator': '2'}]

# %%
ind=-1
for i in exp_list:
    ind+=1
    if (re.search(r'\*', i)):
        result=exp_list2[ind-1])*int(exp_list2[ind+1])
        exp_list2.pop(ind+1)
        exp_list2.pop(ind)
        exp_list2.pop(ind-1)
        exp_list2.insert(ind-1, result)
print(exp_list2)
# Out:
#   File "<ipython-input-60-87364d70ea8c>", line 5
#     result=exp_list2[ind-1])*int(exp_list2[ind+1])
#                            ^
# SyntaxError: unmatched ')'

# %%
while len(exp_list2)>1:
    ind=-1
    for i in exp_list:
        ind+=1
        if type(i)==str:
            if (re.search(r'\*', i)):
                if type(exp_list2[ind-1])==int and type(exp_list2[ind+1])==int:
                    result=exp_list2[ind-1]*exp_list2[ind+1]
                    exp_list2.pop(ind+1)
                    exp_list2.pop(ind)
                    exp_list2.pop(ind-1)
                    exp_list2.insert(ind-1, result)
                elif type(exp_list[ind-1])==dict and type(exp_list[ind+1])==dict:
                    result={}
                    result['whole'] = 0
                    result['numerator'] = (int(exp_list[ind-1]['whole']) * int(exp_list[ind-1]['denominator']) + int(exp_list[ind-1]['numerator']))*((int(exp_list[ind+1]['whole']) * int(exp_list[ind+1]['denominator']))+int(exp_list[ind+1]['numerator']))
                    result['denominator'] = int(exp_list[ind-1]['denominator'])*int(exp_list[ind+1]['denominator'])
                    exp_list2.pop(ind+1)
                    exp_list2.pop(ind)
                    exp_list2.pop(ind-1)
                    exp_list2.insert(ind-1, result)
                elif type(exp_list[ind-1])==int and type(exp_list[ind+1])==dict:
                    result={}
                    result['whole'] = 0
                    result['numerator'] = exp_list[ind-1]*((int(exp_list[ind+1]['whole']) * int(exp_list[ind+1]['denominator']))+int(exp_list[ind+1]['numerator']))
                    result['denominator'] = int(exp_list[ind+1]['denominator'])
                    exp_list2.pop(ind+1)
                    exp_list2.pop(ind)
                    exp_list2.pop(ind-1)
                    exp_list2.insert(ind-1, result)
                elif type(exp_list[ind-1])==dict and type(exp_list[ind+1])==int:
                    result={}
                    result['whole'] = 0
                    result['numerator'] = exp_list[ind+1]*((int(exp_list[ind-1]['whole']) * int(exp_list[ind-1]['denominator']))+int(exp_list[ind-1]['numerator']))
                    result['denominator'] = int(exp_list[ind+1]['denominator'])
                    exp_list2.pop(ind+1)
                    exp_list2.pop(ind)
                    exp_list2.pop(ind-1)
                    exp_list2.insert(ind-1, result)
            if (re.search(r'\/', i)):
                if type(exp_list2[ind-1])==int and type(exp_list2[ind+1])==int:
                    result=exp_list2[ind-1]/exp_list2[ind+1]
                    exp_list2.pop(ind+1)
                    exp_list2.pop(ind)
                    exp_list2.pop(ind-1)
                    exp_list2.insert(ind-1, result)
                elif type(exp_list[ind-1])==dict and type(exp_list[ind+1])==dict:
                    result={}
                    result['whole'] = 0
                    result['numerator'] = (int(exp_list[ind-1]['whole']) * int(exp_list[ind-1]['denominator']) + int(exp_list[ind-1]['numerator']))*int(exp_list[ind+1]['denominator'])
                    result['denominator'] = int(exp_list[ind-1]['denominator'])*((int(exp_list[ind+1]['whole']) * int(exp_list[ind+1]['denominator']))+int(exp_list[ind+1]['numerator']))
                    exp_list2.pop(ind+1)
                    exp_list2.pop(ind)
                    exp_list2.pop(ind-1)
                    exp_list2.insert(ind-1, result)
                elif type(exp_list[ind-1])==int and type(exp_list[ind+1])==dict:
                    result={}
                    result['whole'] = 0
                    result['numerator'] = exp_list[ind-1]*int(exp_list[ind+1]['denominator'])
                    result['denominator'] = ((int(exp_list[ind+1]['whole']) * int(exp_list[ind+1]['denominator']))+int(exp_list[ind+1]['numerator']))
                    exp_list2.pop(ind+1)
                    exp_list2.pop(ind)
                    exp_list2.pop(ind-1)
                    exp_list2.insert(ind-1, result)
                elif type(exp_list[ind-1])==dict and type(exp_list[ind+1])==int:
                    result={}
                    result['whole'] = 0
                    result['numerator'] = exp_list[ind+1]*int(exp_list[ind-1]['denominator'])
                    result['denominator'] = ((int(exp_list[ind-1]['whole']) * int(exp_list[ind-1]['denominator']))+int(exp_list[ind-1]['numerator']))
                    exp_list2.pop(ind+1)
                    exp_list2.pop(ind)
                    exp_list2.pop(ind-1)
                    exp_list2.insert(ind-1, result)
            if (re.search(r'\+', i)):
                if type(exp_list2[ind-1])==int and type(exp_list2[ind+1])==int:
                    result=exp_list2[ind-1]+exp_list2[ind+1]
                    exp_list2.pop(ind+1)
                    exp_list2.pop(ind)
                    exp_list2.pop(ind-1)
                    exp_list2.insert(ind-1, result)
                elif type(exp_list[ind-1])==dict and type(exp_list[ind+1])==dict:
                    result={}
                    result['whole'] = 0
                    result['numerator'] = ((int(exp_list[ind-1]['whole']) * int(exp_list[ind-1]['denominator']) + int(exp_list[ind-1]['numerator']))*int(exp_list[ind+1]['denominator']))+((int(exp_list[ind+1]['whole']) * int(exp_list[ind+1]['denominator']) + int(exp_list[ind+1]['numerator']))*int(exp_list[ind-1]['denominator']))
                    result['denominator'] = int(exp_list[ind-1]['denominator'])*int(exp_list[ind+1]['denominator'])
                    exp_list2.pop(ind+1)
                    exp_list2.pop(ind)
                    exp_list2.pop(ind-1)
                    exp_list2.insert(ind-1, result)
                elif type(exp_list[ind-1])==int and type(exp_list[ind+1])==dict:
                    result={}
                    result['whole'] = 0
                    result['numerator'] = (exp_list[ind-1]*int(exp_list[ind+1]['denominator'])) + ((int(exp_list[ind+1]['whole']) * int(exp_list[ind+1]['denominator']))+int(exp_list[ind+1]['numerator']))
                    result['denominator'] = int(exp_list[ind+1]['denominator'])
                    exp_list2.pop(ind+1)
                    exp_list2.pop(ind)
                    exp_list2.pop(ind-1)
                    exp_list2.insert(ind-1, result)
                elif type(exp_list[ind-1])==dict and type(exp_list[ind+1])==int:
                    result={}
                    result['whole'] = 0
                    result['numerator'] = ((int(exp_list[ind-1]['whole']) * int(exp_list[ind-1]['denominator']))+int(exp_list[ind-1]['numerator'])) + (exp_list[ind+1]*int(exp_list[ind-1]['denominator']))
                    result['denominator'] = int(exp_list[ind-1]['denominator'])
                    exp_list2.pop(ind+1)
                    exp_list2.pop(ind)
                    exp_list2.pop(ind-1)
                    exp_list2.insert(ind-1, result)
            if (re.search(r'\-', i)):
                if type(exp_list2[ind-1])==int and type(exp_list2[ind+1])==int:
                    result=exp_list2[ind-1]-exp_list2[ind+1]
                    exp_list2.pop(ind+1)
                    exp_list2.pop(ind)
                    exp_list2.pop(ind-1)
                    exp_list2.insert(ind-1, result)
                elif type(exp_list[ind-1])==dict and type(exp_list[ind+1])==dict:
                    result={}
                    result['whole'] = 0
                    result['numerator'] = ((int(exp_list[ind-1]['whole']) * int(exp_list[ind-1]['denominator']) + int(exp_list[ind-1]['numerator']))*int(exp_list[ind+1]['denominator']))-((int(exp_list[ind+1]['whole']) * int(exp_list[ind+1]['denominator']) + int(exp_list[ind+1]['numerator']))*int(exp_list[ind-1]['denominator']))
                    result['denominator'] = int(exp_list[ind-1]['denominator'])*int(exp_list[ind+1]['denominator'])
                    exp_list2.pop(ind+1)
                    exp_list2.pop(ind)
                    exp_list2.pop(ind-1)
                    exp_list2.insert(ind-1, result)
                elif type(exp_list[ind-1])==int and type(exp_list[ind+1])==dict:
                    result={}
                    result['whole'] = 0
                    result['numerator'] = (exp_list[ind-1]*int(exp_list[ind+1]['denominator'])) - ((int(exp_list[ind+1]['whole']) * int(exp_list[ind+1]['denominator']))+int(exp_list[ind+1]['numerator']))
                    result['denominator'] = int(exp_list[ind+1]['denominator'])
                    exp_list2.pop(ind+1)
                    exp_list2.pop(ind)
                    exp_list2.pop(ind-1)
                    exp_list2.insert(ind-1, result)
                elif type(exp_list[ind-1])==dict and type(exp_list[ind+1])==int:
                    result={}
                    result['whole'] = 0
                    result['numerator'] = ((int(exp_list[ind-1]['whole']) * int(exp_list[ind-1]['denominator']))-int(exp_list[ind-1]['numerator'])) + (exp_list[ind+1]*int(exp_list[ind-1]['denominator']))
                    result['denominator'] = int(exp_list[ind-1]['denominator'])
                    exp_list2.pop(ind+1)
                    exp_list2.pop(ind)
                    exp_list2.pop(ind-1)
                    exp_list2.insert(ind-1, result)
        exp_list=exp_list2
        continue
final_result=exp_list2[0]
if final_result['numerator']==0:
    ff_result=final_result['whole']
    print(f'Ответ: {ff_result}')
elif final_result['numerator']==final_result['denominator']:
    ff_result=final_result['whole']+1
    print(f'Ответ: {ff_result}')
elif final_result['denominator']==0:
    print('Деление на ноль')
elif final_result['whole']==0:
    ff1=final_result['numerator']
    ff2=final_result['denominator']
    print(f'Ответ: {ff1}/{ff2}')
else:
    ff1=final_result['whole']
    ff2=final_result['numerator']
    ff3=final_result['denominator']
    print(f'Ответ: {ff1}({ff2}/{ff3})')
# Out:
# [{'whole': 0, 'numerator': 0, 'denominator': 4}]
# Ответ: 0

# %%
elif exp_list[ind-1]==dict and exp_list[ind+1]==dict:
            result={}
            result['whole']=0
            result['numerator']=exp_list['name']
