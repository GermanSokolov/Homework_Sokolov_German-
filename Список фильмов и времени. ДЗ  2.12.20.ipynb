# %%
import requests
from bs4 import BeautifulSoup

# %%
base_url = 'https://kinoteatr.ru'

# %%
r = requests.get(f'{base_url}/kinoafisha')

# %%
soap = BeautifulSoup(r.text, 'lxml')

# %%
print(soap)
# Out:
# <!DOCTYPE html>
# <html lang="ru">
# <head>
# <meta charset="utf-8"/>
# <meta content="width=device-width, initial-scale=1, shrink-to-fit=no" name="viewport"/>
# <title>Расписание кино на  сегодня  - купить билеты в  Формула Кино / Синема Парк Москва</title>
# <meta content="Киноафиша на  сегодня Объединенной сети кинотеатров «Формула Кино / Синема Парк» Москва" name="og:title"/>
# <meta content="Киноафиша на  сегодня Объединенной сети кинотеатров «Формула Кино / Синема Парк» Москва" name="twitter:title"/>
# <meta content="Афиша кинотеатров Объединенной киносети «Формула Кино / Синема Парк» в Москве. Цены на билеты и расписание сеансов. Выбирайте удобное время и покупайте билеты онлайн." name="description"/>
# <meta content="Афиша кинотеатров Объединенной киносети «Формула Кино / Синема Парк» в Москве. Цены на билеты и расписание сеансов. Выбирайте удобное время и покупайте билеты онлайн." name="og:description"/>
# ...

# %%
kopa = requests.get(f'https://kinoteatr.ru/film/neposredstvenno-kaha/')

# %%
sopa = BeautifulSoup(kopa.text, 'lxml')

# %%
print(sopa)
# Out:
# <!DOCTYPE html>
# <html lang="ru">
# <head>
# <meta charset="utf-8"/>
# <meta content="width=device-width, initial-scale=1" name="viewport"/>
# <title>
# 	«Непосредственно Каха»  - расписание сеансов, купить билеты онлайн в кинотеатрах Москвы
# </title>
# <meta content="website" property="og:type"/>
# <meta content="
# 	«Непосредственно Каха»  - расписание сеансов, купить билеты онлайн в кинотеатрах Москвы
# " property="og:title"/>
# <meta content="
# 	«Непосредственно Каха»  - расписание сеансов, купить билеты онлайн в кинотеатрах Москвы
# " property="twitter:title"/>
# <meta content="Фильм «Непосредственно Каха»  (2020): цены на билеты и расписание сеансов в кинотеатрах Объединенной киносети «Формула Кино / Синема Парк» в Москве. Покупка электронных билетов онлайн." name="description"/>
# <link href="/apple-touch-icon.png" rel="apple-touch-icon" sizes="180x180"/>
# <link href="/favicon-32x32.png" rel="icon" sizes="32x32" type="image/png"/>
# ...

# %%
films=[]

# %%
for i in soap.findAll('div', class_='movie_card_clickable'):
    timez=[]
    name = i.find('span', class_='movie_card_header title').text.strip()
    age_rating = i.find('i', class_='raiting_sub').text.strip()
    genre = i.findAll('span', class_= 'movie_card_raiting sub_title')[-1].text.strip()
    film_time = i.findAll('span', class_= 'hide-md title')[0].text.strip()
    film_url = i.find('a')['href'].strip()
    kopa = requests.get(film_url)
    sopa = BeautifulSoup(kopa.text, 'lxml')
    for m in sopa.findAll('div', class_='time_block'):
        time = m.findAll('div', class_='time')[0].text.strip()
        if not(time in timez):
            timez.append(time)
    films.append({
        'name': name,
        'age rating': age_rating,
        'genre': genre,
        'time': timez,
        'session shedule': time_shedule
    })
    print(name, genre, film_time, timez, sep='\n', end='\n---------------------\n')
# Out:
# Непосредственно Каха
# 16+
# 			        			                    			комедия, приключения
# 109 мин
# ['00:45\n                                    \n02 дек\n\nВ ночь с 01 декабря на 02 декабря', '00:55\n                                    \n02 дек\n\nВ ночь с 01 декабря на 02 декабря']
# ---------------------
# Взаперти
# 16+
# 			        			                    			триллер
# 90 мин
# ['00:00\n                                    \n02 дек\n\nВ ночь с 01 декабря на 02 декабря', '00:05\n                                    \n02 дек\n\nВ ночь с 01 декабря на 02 декабря', '00:10\n                                    \n02 дек\n\nВ ночь с 01 декабря на 02 декабря', '00:40\n                                    \n02 дек\n\nВ ночь с 01 декабря на 02 декабря', '00:45\n                                    \n02 дек\n\nВ ночь с 01 декабря на 02 декабря', '00:55\n                                    \n02 дек\n\nВ ночь с 01 декабря на 02 декабря']
# ---------------------
# Афера по-голливудски
# 16+
# ...

# %%
for k in sopa.findAll('div',class_='cinema'):
        timez=[]
        cinemas = sopa.find('div', class_='name').text.strip()

# %%
# Out:
# <!DOCTYPE html>
# <html lang="ru">
# <head>
# <meta charset="utf-8"/>
# <meta content="width=device-width, initial-scale=1" name="viewport"/>
# <title>
# 	«Непосредственно Каха»  - расписание сеансов, купить билеты онлайн в кинотеатрах Москвы
# </title>
# <meta content="website" property="og:type"/>
# <meta content="
# 	«Непосредственно Каха»  - расписание сеансов, купить билеты онлайн в кинотеатрах Москвы
# " property="og:title"/>
# <meta content="
# 	«Непосредственно Каха»  - расписание сеансов, купить билеты онлайн в кинотеатрах Москвы
# " property="twitter:title"/>
# <meta content="Фильм «Непосредственно Каха»  (2020): цены на билеты и расписание сеансов в кинотеатрах Объединенной киносети «Формула Кино / Синема Парк» в Москве. Покупка электронных билетов онлайн." name="description"/>
# <link href="/apple-touch-icon.png" rel="apple-touch-icon" sizes="180x180"/>
# <link href="/favicon-32x32.png" rel="icon" sizes="32x32" type="image/png"/>
# ...
